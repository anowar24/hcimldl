# %%
# !pip uninstall numpy

# %%
import pandas as pd
import os
import cv2
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# Load data from train_list.csv
train_csv_file = './train_means_list.csv'
train_df = pd.read_csv(train_csv_file)

train_image_paths = train_df['image'].tolist()
train_scores = train_df['mean_score'].tolist()
data_dir='./resized'
train_images = []
for image_path in train_image_paths:
    print(data_dir)
    print(os.path.join(data_dir, image_path))
    img = cv2.imread(data_dir+image_path)
    img = cv2.resize(img, (256, 192))
    img = img / 255.0
    train_images.append(img)
# Out:
# ./resized
# /english_resized/143.png
# ./resized
# /english_resized/75.png
# ./resized
# /english_resized/24.png
# ./resized
# /english_resized/196.png
# ./resized
# /english_resized/282.png
# ./resized
# /english_resized/20.png
# ./resized
# /english_resized/87.png
# ./resized
# /english_resized/3.png
# ./resized
# /english_resized/81.png
# ./resized
# /english_resized/208.png
# ./resized
# /english_resized/17.png
# ./resized
# /english_resized/316.png
# ./resized
# /foreign_resized/14.png
# ./resized
# /english_resized/37.png
# ./resized
# /english_resized/207.png
# ./resized
# /english_resized/317.png
# ./resized
# /foreign_resized/57.png
# ./resized
# /english_resized/271.png
# ./resized
# /english_resized/57.png
# ./resized
# /english_resized/280.png
# ./resized
# /english_resized/223.png
# ./resized
# /english_resized/98.png
# ./resized
# /english_resized/10.png
# ./resized
# /english_resized/131.png
# ./resized
# /english_resized/142.png
# ./resized
# /english_resized/111.png
# ./resized
# /english_resized/52.png
# ./resized
# /english_resized/21.png
# ./resized
# /foreign_resized/15.png
# ./resized
# /english_resized/303.png
# ./resized
# /english_resized/100.png
# ./resized
# /english_resized/99.png
# ./resized
# /english_resized/261.png
# ./resized
# /english_resized/220.png
# ./resized
# /english_resized/132.png
# ./resized
# /english_resized/181.png
# ./resized
# /english_resized/27.png
# ./resized
# /english_resized/313.png
# ./resized
# /english_resized/62.png
# ./resized
# /english_resized/150.png
# ./resized
# /english_resized/293.png
# ./resized
# /english_resized/339.png
# ./resized
# /english_resized/121.png
# ./resized
# /english_resized/319.png
# ./resized
# /english_resized/323.png
# ./resized
# /english_resized/307.png
# ./resized
# /english_resized/77.png
# ./resized
# /english_resized/179.png
# ./resized
# /english_resized/162.png
# ./resized
# /english_resized/15.png
# ./resized
# /english_resized/333.png
# ./resized
# /english_resized/226.png
# ./resized
# /english_resized/337.png
# ./resized
# /english_resized/216.png
# ./resized
# /foreign_resized/9.png
# ./resized
# /english_resized/183.png
# ./resized
# /english_resized/320.png
# ./resized
# /english_resized/258.png
# ./resized
# /english_resized/228.png
# ./resized
# /english_resized/277.png
# ./resized
# /english_resized/32.png
# ./resized
# /english_resized/145.png
# ./resized
# /english_resized/67.png
# ./resized
# /foreign_resized/49.png
# ./resized
# /foreign_resized/35.png
# ./resized
# /english_resized/236.png
# ./resized
# /english_resized/349.png
# ./resized
# /foreign_resized/12.png
# ./resized
# /english_resized/22.png
# ./resized
# /english_resized/274.png
# ./resized
# /english_resized/54.png
# ./resized
# /english_resized/113.png
# ./resized
# /english_resized/262.png
# ./resized
# /english_resized/192.png
# ./resized
# /english_resized/211.png
# ./resized
# /english_resized/214.png
# ./resized
# /foreign_resized/36.png
# ./resized
# /english_resized/122.png
# ./resized
# /english_resized/167.png
# ./resized
# /english_resized/344.png
# ./resized
# /english_resized/152.png
# ./resized
# /english_resized/295.png
# ./resized
# /english_resized/74.png
# ./resized
# /foreign_resized/3.png
# ./resized
# /english_resized/212.png
# ./resized
# /english_resized/109.png
# ./resized
# /foreign_resized/53.png
# ./resized
# /foreign_resized/30.png
# ./resized
# /english_resized/116.png
# ./resized
# /english_resized/275.png
# ./resized
# /english_resized/336.png
# ./resized
# /english_resized/198.png
# ./resized
# /english_resized/49.png
# ./resized
# /english_resized/268.png
# ./resized
# /english_resized/70.png
# ./resized
# /english_resized/186.png
# ./resized
# /english_resized/286.png
# ./resized
# /english_resized/299.png
# ./resized
# /english_resized/5.png
# ./resized
# /english_resized/55.png
# ./resized
# /english_resized/163.png
# ./resized
# /english_resized/331.png
# ./resized
# /english_resized/347.png
# ./resized
# /english_resized/155.png
# ./resized
# /english_resized/309.png
# ./resized
# /english_resized/2.png
# ./resized
# /english_resized/166.png
# ./resized
# /english_resized/326.png
# ./resized
# /english_resized/161.png
# ./resized
# /english_resized/51.png
# ./resized
# /english_resized/227.png
# ./resized
# /english_resized/253.png
# ./resized
# /english_resized/251.png
# ./resized
# /english_resized/288.png
# ./resized
# /english_resized/324.png
# ./resized
# /foreign_resized/48.png
# ./resized
# /foreign_resized/2.png
# ./resized
# /foreign_resized/16.png
# ./resized
# /english_resized/149.png
# ./resized
# /english_resized/205.png
# ./resized
# /english_resized/188.png
# ./resized
# /foreign_resized/24.png
# ./resized
# /english_resized/329.png
# ./resized
# /english_resized/82.png
# ./resized
# /english_resized/330.png
# ./resized
# /english_resized/284.png
# ./resized
# /english_resized/65.png
# ./resized
# /foreign_resized/39.png
# ./resized
# /english_resized/66.png
# ./resized
# /english_resized/294.png
# ./resized
# /foreign_resized/37.png
# ./resized
# /english_resized/46.png
# ./resized
# /english_resized/59.png
# ./resized
# /english_resized/45.png
# ./resized
# /english_resized/335.png
# ./resized
# /english_resized/103.png
# ./resized
# /english_resized/19.png
# ./resized
# /english_resized/68.png
# ./resized
# /english_resized/311.png
# ./resized
# /foreign_resized/17.png
# ./resized
# /foreign_resized/47.png
# ./resized
# /english_resized/237.png
# ./resized
# /english_resized/4.png
# ./resized
# /foreign_resized/41.png
# ./resized
# /english_resized/343.png
# ./resized
# /english_resized/141.png
# ./resized
# /english_resized/204.png
# ./resized
# /english_resized/260.png
# ./resized
# /english_resized/85.png
# ./resized
# /english_resized/115.png
# ./resized
# /english_resized/47.png
# ./resized
# /english_resized/156.png
# ./resized
# /english_resized/246.png
# ./resized
# /english_resized/33.png
# ./resized
# /english_resized/1.png
# ./resized
# /english_resized/159.png
# ./resized
# /english_resized/270.png
# ./resized
# /english_resized/106.png
# ./resized
# /english_resized/213.png
# ./resized
# /foreign_resized/40.png
# ./resized
# /english_resized/125.png
# ./resized
# /foreign_resized/6.png
# ./resized
# /foreign_resized/4.png
# ./resized
# /english_resized/239.png
# ./resized
# /english_resized/341.png
# ./resized
# /english_resized/224.png
# ./resized
# /english_resized/304.png
# ./resized
# /english_resized/225.png
# ./resized
# /english_resized/334.png
# ./resized
# /english_resized/278.png
# ./resized
# /english_resized/76.png
# ./resized
# /english_resized/328.png
# ./resized
# /english_resized/63.png
# ./resized
# /foreign_resized/27.png
# ./resized
# /foreign_resized/20.png
# ./resized
# /english_resized/153.png
# ./resized
# /english_resized/86.png
# ./resized
# /english_resized/12.png
# ./resized
# /english_resized/249.png
# ./resized
# /english_resized/308.png
# ./resized
# /english_resized/50.png
# ./resized
# /english_resized/267.png
# ./resized
# /english_resized/172.png
# ./resized
# /english_resized/247.png
# ./resized
# /english_resized/128.png
# ./resized
# /foreign_resized/29.png
# ./resized
# /english_resized/71.png
# ./resized
# /foreign_resized/25.png
# ./resized
# /english_resized/88.png
# ./resized
# /english_resized/325.png
# ./resized
# /english_resized/135.png
# ./resized
# /english_resized/182.png
# ./resized
# /english_resized/233.png
# ./resized
# /english_resized/264.png
# ./resized
# /english_resized/151.png
# ./resized
# /foreign_resized/43.png
# ./resized
# /english_resized/129.png
# ./resized
# /english_resized/11.png
# ./resized
# /english_resized/197.png
# ./resized
# /english_resized/200.png
# ./resized
# /english_resized/108.png
# ./resized
# /english_resized/176.png
# ./resized
# /foreign_resized/51.png
# ./resized
# /english_resized/291.png
# ./resized
# /english_resized/102.png
# ./resized
# /english_resized/120.png
# ./resized
# /english_resized/338.png
# ./resized
# /english_resized/90.png
# ./resized
# /foreign_resized/19.png
# ./resized
# /foreign_resized/55.png
# ./resized
# /english_resized/256.png
# ./resized
# /english_resized/210.png
# ./resized
# /english_resized/302.png
# ./resized
# /foreign_resized/58.png
# ./resized
# /english_resized/218.png
# ./resized
# /english_resized/242.png
# ./resized
# /english_resized/41.png
# ./resized
# /english_resized/289.png
# ./resized
# /english_resized/292.png
# ./resized
# /english_resized/36.png
# ./resized
# /english_resized/89.png
# ./resized
# /foreign_resized/7.png
# ./resized
# /english_resized/64.png
# ./resized
# /foreign_resized/11.png
# ./resized
# /english_resized/244.png
# ./resized
# /english_resized/96.png
# ./resized
# /foreign_resized/34.png
# ./resized
# /english_resized/265.png
# ./resized
# /english_resized/114.png
# ./resized
# /foreign_resized/44.png
# ./resized
# /english_resized/322.png
# ./resized
# /english_resized/276.png
# ./resized
# /english_resized/80.png
# ./resized
# /english_resized/346.png
# ./resized
# /english_resized/69.png
# ./resized
# /english_resized/217.png
# ./resized
# /english_resized/112.png
# ./resized
# /english_resized/348.png
# ./resized
# /english_resized/58.png
# ./resized
# /foreign_resized/54.png
# ./resized
# /english_resized/39.png
# ./resized
# /english_resized/189.png
# ./resized
# /english_resized/105.png
# ./resized
# /english_resized/318.png
# ./resized
# /foreign_resized/1.png
# ./resized
# /foreign_resized/42.png
# ./resized
# /english_resized/345.png
# ./resized
# /english_resized/16.png
# ./resized
# /english_resized/290.png
# ./resized
# /english_resized/34.png
# ./resized
# /english_resized/259.png
# ./resized
# /foreign_resized/32.png
# ./resized
# /english_resized/30.png
# ./resized
# /english_resized/72.png
# ./resized
# /english_resized/104.png
# ./resized
# /english_resized/83.png
# ./resized
# /english_resized/187.png
# ./resized
# /english_resized/144.png
# ./resized
# /english_resized/298.png
# ./resized
# /english_resized/97.png
# ./resized
# /english_resized/171.png
# ./resized
# /english_resized/315.png
# ./resized
# /english_resized/0.png
# ./resized
# /english_resized/190.png
# ./resized
# /foreign_resized/46.png
# ./resized
# /english_resized/235.png
# ./resized
# /english_resized/134.png
# ./resized
# /english_resized/48.png
# ./resized
# /english_resized/136.png
# ./resized
# /english_resized/206.png
# ./resized
# /english_resized/18.png
# ./resized
# /english_resized/272.png
# ./resized
# /english_resized/184.png
# ./resized
# /english_resized/310.png
# ./resized
# /foreign_resized/21.png
# ./resized
# /english_resized/133.png
# ./resized
# /english_resized/40.png
# ./resized
# /english_resized/240.png
# ./resized
# /english_resized/287.png
# ./resized
# /english_resized/160.png
# ./resized
# /foreign_resized/31.png
# ./resized
# /english_resized/273.png
# ./resized
# /foreign_resized/52.png
# ./resized
# /english_resized/269.png
# ./resized
# /english_resized/7.png
# ./resized
# /english_resized/306.png
# ./resized
# /english_resized/248.png
# ./resized
# /english_resized/263.png
# ./resized
# /english_resized/93.png
# ./resized
# /english_resized/229.png
# ./resized
# /english_resized/56.png
# ./resized
# /foreign_resized/23.png
# ./resized
# /english_resized/168.png
# ./resized
# /english_resized/221.png
# ./resized
# /english_resized/215.png
# ./resized
# /english_resized/209.png
# ./resized
# /english_resized/119.png
# ./resized
# /english_resized/23.png
# ./resized
# /english_resized/245.png
# ./resized
# /english_resized/219.png

# %%
# Load data from test_list.csv
test_csv_file = './test_list.csv'
test_df = pd.read_csv(test_csv_file)

test_image_paths = test_df['image'].tolist()
test_scores = test_df['mean_score'].tolist()
data_dir='./resized'
test_images = []
for image_path in test_image_paths:
    img = cv2.imread(data_dir+ image_path)
    img = cv2.resize(img, (256, 192))
    img = img / 255.0
    test_images.append(img)

test_images = np.array(test_images)
test_scores = np.array(test_scores)

# %%
# Combine train and test data
images = np.concatenate((train_images, test_images), axis=0)
scores = np.concatenate((train_scores, test_scores), axis=0)

# %%
# Split the combined data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(images, scores, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Define the CNN architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(192, 256, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])
# Out:
# 2023-06-01 22:16:59.757180: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile and train the CNN model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 3s 297ms/step - loss: 3459.0190 - mae: 26.9078 - val_loss: 6.2812 - val_mae: 2.1271
# Epoch 2/10
# 8/8 [==============================] - 2s 279ms/step - loss: 6.7895 - mae: 2.2136 - val_loss: 3.1552 - val_mae: 1.4533
# Epoch 3/10
# 8/8 [==============================] - 2s 294ms/step - loss: 3.2831 - mae: 1.4683 - val_loss: 2.5292 - val_mae: 1.2585
# Epoch 4/10
# 8/8 [==============================] - 2s 281ms/step - loss: 2.5522 - mae: 1.2558 - val_loss: 2.5123 - val_mae: 1.2351
# Epoch 5/10
# 8/8 [==============================] - 2s 286ms/step - loss: 2.0197 - mae: 1.1166 - val_loss: 2.1027 - val_mae: 1.1238
# Epoch 6/10
# 8/8 [==============================] - 2s 296ms/step - loss: 1.7285 - mae: 1.0198 - val_loss: 1.8484 - val_mae: 1.0088
# Epoch 7/10
# 8/8 [==============================] - 2s 294ms/step - loss: 1.5517 - mae: 0.9558 - val_loss: 1.8484 - val_mae: 1.0029
# Epoch 8/10
# 8/8 [==============================] - 2s 299ms/step - loss: 1.4295 - mae: 0.9204 - val_loss: 1.9605 - val_mae: 1.0846
# Epoch 9/10
# 8/8 [==============================] - 2s 286ms/step - loss: 1.2527 - mae: 0.8602 - val_loss: 1.8448 - val_mae: 1.0106
# Epoch 10/10
# 8/8 [==============================] - 2s 280ms/step - loss: 1.1880 - mae: 0.8331 - val_loss: 1.9278 - val_mae: 1.0314

# %%
# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print('Test Loss:', test_loss)
print('Test MAE:', test_mae)
# Out:
# 3/3 [==============================] - 0s 36ms/step - loss: 1.9776 - mae: 1.0502
# Test Loss: 1.9775772094726562
# Test MAE: 1.0502445697784424
